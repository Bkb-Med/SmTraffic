# %%
# !pwd
# Out:
# /content/drive/My Drive/Smart_Traffic/sm_v4/yolov4-deepsort

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Smart_Traffic/sm_v4/
# Out:
# /content/drive/MyDrive/Smart_Traffic/sm_v4

# %%
# %cd yolov4-deepsort/
# Out:
# /content/drive/My Drive/Smart_Traffic/sm_v4/yolov4-deepsort

# %%
# !pip install git+https://github.com/ozgur/python-firebase
# Out:
# ...
#   Cloning https://github.com/ozgur/python-firebase to /tmp/pip-req-build-lwocquk9
#   Running command git clone -q https://github.com/ozgur/python-firebase /tmp/pip-req-build-lwocquk9
# ...
#   Created wheel for python-firebase: filename=python_firebase-1.2.1-cp37-none-any.whl size=12533 sha256=e1ba64be14f29275bc19f09d4cbd1b5f5230be596096bb62028b23a25d7b0f12
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zl9rpf_q/wheels/ef/40/57/99d925b3495995b9930edfb8f4033cb9a8dbf838848d5a65ba
# Successfully built python-firebase

# %%
# !python object_tracker.py --video ./data/video/croisement.mp4 --output ./outputs/trackercoisement.avi --model yolov4 --dont_show
# Out:
# +--------snapshot(15s)---------
# | Frame #:  175
# | FPS: 13.99
# dispx A :: 0.0
# dispx A :: 0.0
# dispx A :: 0.0
# dispx A :: 0.0
# dispx A :: 0.0
# dispx A :: 0.0
# | car count A # : 0
# | car count B # : 0
# | average speed A # : 0km
# | average speed B # : 0km
# yA value #:62
# yB value #:62
# +--------snapshot(15s)---------
# | Frame #:  298
# | FPS: 9.71
# dispx A :: 23.584971910095632
# dispx A :: 180.87533883865984
# dispx B :: 167.9022409022584
# dispx B :: 163.2607760608774
# dispx B :: 0.4901020301937228
# dispx B :: 0.1303840481039344
# dispx B :: 0.6199999999998909
# dispx A :: 178.12859652509476
# dispx A :: 173.75241724937243
# dispx A :: 87.25000057306592
# dispx A :: 81.05419544971126
# dispx A :: 49.149323494835585
# dispx B :: 64.76912304485833
# dispx A :: 35.28049461104537
# dispx A :: 310.8777253197791
# dispx A :: 149.61665582414275
# dispx A :: 119.44537370697955
# dispx B :: 2.2429444932944627
# dispx A :: 83.37978232161565
# | car count A # : 12
# ...
